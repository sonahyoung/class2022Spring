# %% [markdown]
# <a href="https://colab.research.google.com/github/sonahyoung/class2022Spring/blob/main/requests_gradio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# API 서비스
#
# -> 구글링
#
# -> application programming interface
#
# -> 개발자가 다른 서버나 컴퓨터, database에 있는 것을 연결, interface해주는 거임
#
# -> 미세먼지 이런거 볼 수 있는 게 공공 api라고 해서 거기서 제공해주는 거임, 프로그램 속에 포함시킬 수 있도록 해주는 게 api
#
# ex. 자동 번역 api

# %% [markdown]
# requests라는 library를 사용하는 방법만 배우면 api를 마음 놓고 쓸 수 있음

# %% [markdown]
# 공공 데이터 api를 google에 검색해보면
# 공공데이터포털 있음
#
# api = 다른 데에 컴퓨터가 있는데 부품처럼 사용할 수 있도록 해주는 것
#
# 데이터활용-공공데이터활용사례-날씨소녀(날씨앱을 만든거임)
#
# -활용데이터 오픈 api를 열어보기
#
# *REST API - 규약 중에 대표적인 것
#
# *데이터포맷 -> 아래한글, 워드, 텍스트 이런 형식
# (JSON + XML) 이 두개가 가장 대표적인 것 (JSON이 정말 많이 씀)
#
# 아래 내려가보면, 요청변수가 있음(이건 다 api마다 다를 거임)
#
# SeriveKey, pageNo 이런 것들 있음
#
# 또 출력결과가 있음

# %% [markdown]
# 데이터찾기-데이터목록-미세먼지검색
# (csv, pdf 다 있는데 프로그래밍을 하는거니까 오픈 api를 봐야함)
#
# 그 중에서 '한국환경공단_에어코리아 미세먼지 경보 발령현황' 클릭

# %% [markdown]
# 여기 말고 또 api하는 곳이 있음. 네이버 api가 유명함
#
# 네이버 개발자 센터 - 네이버 오픈 api 목록
#
# kakao api도 있음. Kakao Developers - REST API
# (유명한 거 REST라고 아까 말했던거임)
#
# 제품 전체보기 하면 비즈니스 API, 인공지능 API 있음

# %%
#!pip install gradio
#import gradio as gr
#import pandas as pd
import requests

# %%
requests.get('http://apis.data.go.kr/B552584/UlfptcaAlarmInqireSvc/getUlfptcaAlarmInfo?year=2020&pageNo=1&numOfRows=100&returnType=xml&serviceKey=서비스키') 
#()안에는 url을 써주면 됨. copy해서 paste한걸 붙이면 그 문서의 응답메시지꺼가 나옴.
#string으로 써줌.
#기본적으로 인터넷 주소를 주면, 서버에서 답을 주는 거임. 이런 식으로 url 방식으로 api 서버에 던지고 그런거를 REST API라고 함

# %% [markdown]
# 다운 받은 매뉴얼을 보면,
#
# 0.1에서는 그냥 실시간으로 어떤 정보를 주는지 나와있음.
#
# 0.2 데이터 생성주기에서는 시군구별 실시간 평균정보 조회의 getCtprvnMesureSidoList만 관심가지면 됨.
#
# 1.1 가. 에서 보면
#
# API 이름이 나와있고 서비스 인증/권한의 ServiceKey를 받을 거고, 교환 데이터 표준에서는, output으로 받는 데이터의 형태에 XML, JSON의 형태를 쓸 수 있음. 우리는 JSON을 쓸거임.
#
# 아래로 내리면 요청/응답 메시지 예제가 나와있음. 이걸 copy해서 requests.get을 paste하면 되는 거임.

# %%
#위의 코드 말고 아래 있는 코드만 보면 됨

# %%
URL = ('http://apis.data.go.kr/B552584/ArpltnStatsSvc/'  #이거는 API 서비스 개요에서 서비스 url과 일치함. - 서비스 URL
      'getCtprvnMesureSidoLIst?'  #이거는 구체적인 세부서비스임. 아까 그거 시군구별 실시간 평균정보 조회 그걸 적어준거임. - 서비스 이름
      'sidoName=서울'
      '&searchCondition=hour' #매시간마다 하는 것
      '&pageNo=1'
      '&numOfRows=100'
      '&returnType=json'  #json의 형태로 받고 싶다
      '&serviceKey=miH%2BZXg85lQy4%2FkmhffvygXDIFiTwisriSLxtyECSzw6hxTVK7yI8QKIOc7mP7LEqCnhBGuj6iW1gZW65dum7A%3D%3D')
#serviceKey는 암호조항임. 가입하면 다 줌.
#sidoName 같은 첫번째는 그냥 적어도 되는데 그 다음부터는 &로 받아야함
#상세서비스 이름, 항목들은 다 manual에 적혀있음
response = requests.get(URL)
#request에 보내면 사실상 api는 끝난거임. 그 뒤에는 예쁘게 보려고 하는 거임.

# %%
response  #결과값 200은 구글에 response code requests python 200을 쳐보면 되는데, 200은 잘 처리가 되었다고 얘기하는 거임.
# Out:
# <Response [200]>

# %% [markdown]
# #### http://jsonviewer.stack.hu/ (copy json here to view json)

# %%
r = response.json()  #내용을 받으려면 이렇게 하면 됨.
r #서울 강남구부터 해서 쭉 나와있음. json 타입으로 나와있는 거임. 근데 너무 복잡함
#위의 사이트에 결과값을 붙여놓고 viewer하면
#JSON - response - body - items - 0, 1, 2 ... 뭐 이런식으로 정리되어서 나옴. json의 형태가 이런거구나 알기
# Out:
# {'response': {'body': {'items': [{'cityName': '강남구',
#      'cityNameEng': 'Gangnam-gu',
#      'coValue': '0.4',
#      'dataGubun': '',
#      'dataTime': '2022-03-26 15:00',
#      'districtCode': '02',
#      'districtNumSeq': '001',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.014',
#      'numOfRows': '10',
#      'o3Value': '0.040',
#      'pageNo': '1',
#      'pm10Value': '8',
#      'pm25Value': '3',
#      'resultCode': '',
#      'resultMsg': '',
#      'returnType': 'json',
#      'searchCondition': '',
#      'serviceKey': '',
#      'sidoName': '서울',
#      'so2Value': '0.003',
#      'totalCount': ''},
#     {'cityName': '강동구',
#      'cityNameEng': 'Gangdong-gu',
#      'coValue': '0.3',
#      'dataGubun': '',
#      'dataTime': '2022-03-26 15:00',
#      'districtCode': '02',
#      'districtNumSeq': '002',
#      'itemCode': '',
#      'khaiValue': '',
#      'no2Value': '0.012',
#      'numOfRows': '10',
#      'o3Value': '0.030',
# ...

# %%
print(type(r))

#dict - z{key : values}
#z[key] 이런식으로 하면 values가 access됨
# Out:
# <class 'dict'>

# %%
items = r['response']['body']['items']  #json-response-body-items 이게 다 key 값이라고 생각하면 됨
items #강남구부터 해서 24개 들어있을 거임, items는 list로 되어 있음. 
#그 안에 강남구를 봐보면 dict로 들어와있음. 다른 것도 dict로 들어있음
# Out:
# [{'cityName': '강남구',
#   'cityNameEng': 'Gangnam-gu',
#   'coValue': '0.4',
#   'dataGubun': '',
#   'dataTime': '2022-03-26 15:00',
#   'districtCode': '02',
#   'districtNumSeq': '001',
#   'itemCode': '',
#   'khaiValue': '',
#   'no2Value': '0.014',
#   'numOfRows': '10',
#   'o3Value': '0.040',
#   'pageNo': '1',
#   'pm10Value': '8',
#   'pm25Value': '3',
#   'resultCode': '',
#   'resultMsg': '',
#   'returnType': 'json',
#   'searchCondition': '',
#   'serviceKey': '',
#   'sidoName': '서울',
#   'so2Value': '0.003',
#   'totalCount': ''},
#  {'cityName': '강동구',
#   'cityNameEng': 'Gangdong-gu',
#   'coValue': '0.3',
#   'dataGubun': '',
#   'dataTime': '2022-03-26 15:00',
#   'districtCode': '02',
#   'districtNumSeq': '002',
#   'itemCode': '',
#   'khaiValue': '',
#   'no2Value': '0.012',
#   'numOfRows': '10',
#   'o3Value': '0.030',
#   'pageNo': '1',
#   'pm10Value': '20',
#   'pm25Value': '2',
#   'resultCode': '',
#   'resultMsg': '',
#   'returnType': 'json',
# ...

# %%
items = r['response']['body']['items']
items[0]  #강남구꺼만 나올거임
# Out:
# {'cityName': '강남구',
#  'cityNameEng': 'Gangnam-gu',
#  'coValue': '0.4',
#  'dataGubun': '',
#  'dataTime': '2022-03-26 15:00',
#  'districtCode': '02',
#  'districtNumSeq': '001',
#  'itemCode': '',
#  'khaiValue': '',
#  'no2Value': '0.014',
#  'numOfRows': '10',
#  'o3Value': '0.040',
#  'pageNo': '1',
#  'pm10Value': '8',
#  'pm25Value': '3',
#  'resultCode': '',
#  'resultMsg': '',
#  'returnType': 'json',
#  'searchCondition': '',
#  'serviceKey': '',
#  'sidoName': '서울',
#  'so2Value': '0.003',
#  'totalCount': ''}

# %% [markdown]
# 이런걸 pandas로 excel파일처럼 정리할거임.
#
# 도시명, pm10, pm25, so2 이런 게 excel의 column이 될거임.
#
# 도시명에 강남구, 강동구 이런 게 row에 들어갈거임.
#
# data frame을 pandas를 통해 만들고자 함.

# %% [markdown]
# pd.Series를 통해 column에 들어가는 data 값들을 가져옴.

# %%
import pandas as pd
cityName = [item['cityName'] for item in items]  #25번을 돌거임. 그 item 중에서 cityName이 있는 것을 넣어라. ex) 강남구, 강동구....
pm10Value = [item['pm10Value'] for item in items]
pm25Value = [item['pm25Value'] for item in items]
so2Value = [item['so2Value'] for item in items]
coValue = [item['coValue'] for item in items]
o3Value = [item['o3Value'] for item in items]
no2Value = [item['no2Value'] for item in items]

#pd.Series를 이용해서 7개의 column을 만듬.
cityName = pd.Series(cityName)
pm10Value = pd.Series(pm10Value)   
pm25Value = pd.Series(pm25Value)
so2Value = pd.Series(so2Value)
coValue = pd.Series(coValue)
o3Value = pd.Series(o3Value)
no2Value = pd.Series(no2Value)

df = pd.DataFrame({ 'cityName': cityName, 'pm10Value': pm10Value, 'pm25Value': pm25Value, 'so2Value': so2Value, 'coValue': coValue, 'o3Value': o3Value, 'no2Value': no2Value})
#왼쪽의 'cityName', 'pm10Value' 이런거는 column명을 넣고, dict의 value값으로 들어가는 것은 위의 pd.Series에서 = 왼쪽 부분을 써주면 됨.

# %%
df
# Out:
#    cityName pm10Value pm25Value so2Value coValue o3Value no2Value
# 0       강남구         8         3    0.003     0.4   0.040    0.014
# 1       강동구        20         2    0.002     0.3   0.030    0.012
# 2       강북구         4         2    0.002     0.4   0.047    0.004
# 3       강서구         6         2    0.002     0.4   0.048    0.010
# 4       관악구                   2    0.002     0.5   0.040    0.015
# 5       광진구         3         1    0.004     0.4   0.041    0.011
# 6       구로구        10         2    0.003     0.4   0.042    0.010
# 7       금천구         5         3    0.003     0.3   0.041    0.015
# 8       노원구         4         1    0.003     0.4   0.044    0.008
# 9       도봉구         3         3    0.003     0.4   0.044    0.006
# 10     동대문구         7         2    0.002     0.4   0.045    0.010
# 11      동작구         7         3    0.002     0.4   0.043    0.013
# 12      마포구        10         2    0.003     0.4   0.042    0.018
# ...

# %%
def test(sidoName):   #위의 과정을 function의 형태로 만들어준거임.
  URL = ('http://apis.data.go.kr/B552584/ArpltnStatsSvc/'
      'getCtprvnMesureSidoLIst?'
      'sidoName='+sidoName+
      '&searchCondition=hour'
      '&pageNo=1'
      '&numOfRows=100'
      '&returnType=json'
      '&serviceKey=miH%2BZXg85lQy4%2FkmhffvygXDIFiTwisriSLxtyECSzw6hxTVK7yI8QKIOc7mP7LEqCnhBGuj6iW1gZW65dum7A%3D%3D')
  
  response = requests.get(URL)
  r = response.json()
  items = r['response']['body']['items']

  cityName = [item['cityName'] for item in items]
  pm10Value = [item['pm10Value'] for item in items]
  pm25Value = [item['pm25Value'] for item in items]
  so2Value = [item['so2Value'] for item in items]
  coValue = [item['coValue'] for item in items]
  o3Value = [item['o3Value'] for item in items]
  no2Value = [item['no2Value'] for item in items]

  cityName = pd.Series(cityName)
  pm10Value = pd.Series(pm10Value)   
  pm25Value = pd.Series(pm25Value)
  so2Value = pd.Series(so2Value)
  coValue = pd.Series(coValue)
  o3Value = pd.Series(o3Value)
  no2Value = pd.Series(no2Value)

  df = pd.DataFrame({ 'cityName': cityName, 'pm10Value': pm10Value, 'pm25Value': pm25Value, 'so2Value': so2Value, 'coValue': coValue, 'o3Value': o3Value, 'no2Value': no2Value})
  return df

# %%
# !pip install gradio  #function의 세가지: install, import, built-in이 있다고 했는데, install을 하려면 !pip install하면 됨.

# %%
import gradio as gr

# %%
iface = gr.Interface(test, gr.inputs.Dropdown(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주', '세종']), outputs=['dataframe'])
iface.launch(debug=True)
# Out:
# (<fastapi.applications.FastAPI at 0x7f75d4ebe410>,
#  'http://127.0.0.1:7860/',
#  'https://39697.gradio.app')

# %%
#이렇게 프로그램을 만든거임.

# %% [markdown]
# <복습>
#
# 키워드 : API (다른 서버에서 서비스해준 거를 가져와서 gradio라는 일종의 웹 데모 만드는 것
#
# API 접근 방법 -> python에서 request를 써봤음
#
# API를 사용하려면 service key가 있어야하는데, 계정 만들면 주어지는 것임.
#
#
# Gradio -> 연결해서 받아온걸 웹 데모 만들어줌
